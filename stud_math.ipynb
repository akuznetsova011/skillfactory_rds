# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

stud_math = pd.read_csv('stud_math.csv')

# %%
# Рассмотрим, какие данные хранятся в файле и какие типы данных у столбцов:
display(stud_math.head(10))
stud_math.info() 

# В датасете 13 числовых столбцов и 17 строковых
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0   at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0    health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5     GP   M   16       U     LE3       T   4.0   3.0  services    other
# 6     GP   M   16     NaN     LE3       T   2.0   2.0     other    other
# 7     GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 8     GP   M   15       U     LE3       A   3.0   2.0  services    other
# 9     GP   M   15       U     NaN     NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %%
# Посмотрим, сколько школ в нашем датасете

pd.DataFrame(stud_math.school.value_counts())
# Out:
#     school
# GP     349
# MS      46

# %%
# Так как школ только две, заменим значение "GP" на "0", "MS" - на "1"

stud_math.school = stud_math.school.astype(str).apply(lambda x: '0' if x.strip() == 'GP' else '1')

# %%
# Заменим пол "M" на "0", "F" - на "1"

stud_math.sex = stud_math.sex.astype(str).apply(lambda x: '0' if x.strip() == 'M' else '1')
display(stud_math)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        0   1   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1        0   1   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2        0   1   15       U     LE3       T   1.0   1.0   at_home     other
# 3        0   1   15       U     GT3       T   4.0   2.0    health       NaN
# 4        0   1   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390      1   0   20       U     LE3       A   2.0   2.0  services  services
# 391      1   0   17       U     LE3       T   3.0   1.0  services  services
# 392      1   0   21       R     GT3       T   1.0   1.0     other     other
# 393      1   0   18       R     LE3       T   3.0   2.0  services     other
# 394      1   0   19       U     LE3       T   1.0   1.0     other   at_home
#
# ...

# %%
# Посмотрим на распределение значений столбца "age"

stud_math.age.hist(bins=8)
stud_math.age.describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
boxplot = stud_math.boxplot(column=['age'])

# видим, что есть выбросы

# %%
# Посмотрим, сколько адресов у нас в датасете

pd.DataFrame(stud_math.address.value_counts(dropna=False))
# Out:
#      address
# U        295
# R         83
# NaN       17

# %%
# Видим, что пустых строк всего 17

# %%
# Заменим адрес "U" на "0" и "R" - на "1". 

stud_math.address = stud_math.address.astype(str).apply(lambda x: '0' if x.strip() == 'U' '1' if x.strip() == 'R' else x) 
# display(stud_math)
# Out:
#   File "<ipython-input-30-fa8102c6ccfa>", line 3
#     stud_math.address = stud_math.address.astype(str).apply(lambda x: '0' if x.strip() == 'U' '1'if x.strip() == 'R' else x)
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
# stud_math.famsize = stud_math.famsize.apply(lambda x: None if x == '' else x)
# pd.DataFrame(stud_math.famsize.value_counts())
# display(stud_math.head(10))
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0      0   1   18       1     NaN       A   4.0   4.0   at_home  teacher
# 1      0   1   17       1     GT3     NaN   1.0   1.0   at_home    other
# 2      0   1   15       1     LE3       T   1.0   1.0   at_home    other
# 3      0   1   15       1     GT3       T   4.0   2.0    health      NaN
# 4      0   1   16       1     GT3       T   3.0   3.0     other    other
# 5      0   0   16       1     LE3       T   4.0   3.0  services    other
# 6      0   0   16       1     LE3       T   2.0   2.0     other    other
# 7      0   1   17       1     GT3       A   4.0   4.0     other  teacher
# 8      0   0   15       1     LE3       A   3.0   2.0  services    other
# 9      0   0   15       1     NaN     NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %%
# Посмотрим на распределение значений столбца "score"

stud_math.score.hist(bins=12)
stud_math.score.describe()
# Out:
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64
